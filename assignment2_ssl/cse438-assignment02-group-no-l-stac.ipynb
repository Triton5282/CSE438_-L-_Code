jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0027661_jpg.rf.0f9c35c2502efbe3c61c3b2692b249ca.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0024344_jpg.rf.55f6df9e025e01307b73f69a3a3d69e1.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0031207_jpg.rf.e29e4f68a5e2e32f214e73c76f475c86.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0028377_jpg.rf.a7f633489db9a0606769e2bffba7b35c.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0029011_jpg.rf.0dfaae750dccb8f5e6c02226a606e10e.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0029734_jpg.rf.94933e54b29c26d6f917b21e6bd98db8.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0032845_jpg.rf.2c235a5890e6153c9c8fd9033e8c4b24.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0028832_jpg.rf.b8da4fb9065e90a87585b07aa8331e89.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0027521_jpg.rf.16796c2b1544b2cbf3c094f9eb5ed869.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0031053_jpg.rf.88f52b7cfd4f020fb810923477c78caa.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0033957_jpg.rf.ab6c2c70d9599594c2443e8bc3d3bece.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0026651_jpg.rf.0a666b0e88301bc9ce43078992ee09f3.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0026845_jpg.rf.fd6a4526fe643ded430b8e50425ff1b2.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0025221_jpg.rf.0262c64e36c90ed151e625113ff2dc05.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0030024_jpg.rf.39389ffb89955420c889587bc6a319fe.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0030285_jpg.rf.caf7f5f23a143e13926b12d9dcd5f81a.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0025876_jpg.rf.0159c03f2edeb1340bee3ab2e73ce703.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0026963_jpg.rf.c1281ded3fba82090ed9570033bfae5c.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0032988_jpg.rf.21560228db39e53e26dfe5496b1554df.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0024960_jpg.rf.e39b4a4daca82176f22580ed89ab1471.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0027490_jpg.rf.a58d9c09a3a87c8e9e2d3fd9dbb7a7d2.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0033731_jpg.rf.450d8c5b1308d75f077da9d2bda3d8bf.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0025902_jpg.rf.de48034ea933ec9179da7c11dd72ab6f.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0033717_jpg.rf.5c43e0776148e44557fa641f9fee5116.jpg
# /kaggle/input/skin-cancer-segmentation/train/ISIC_0031360_jpg.rf.7ff6f949fcf2e57e6d3d30e6d1715053.jpg

# %%
# !pip -q install --upgrade --no-warn-script-location ultralytics albumentations pycocotools torchmetrics tqdm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 25.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 107.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 110.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 34.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# tensorflow 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.

# %% [markdown]
# ## 🧩 COCO → YOLO Segmentation Conversion
#
# This section converts the **COCO-format segmentation dataset** into the **YOLO segmentation format**, preparing it for YOLOv8 or YOLOv11 segmentation model training using the **Ultralytics** framework.
#
# ---
#
# #### ⚙️ Step 1: Library Installation
# The following Python packages are installed:
# - **`pycocotools`** → to handle COCO JSON annotations
# - **`tqdm`** → for progress visualization
# - **`ultralytics`** → YOLO training and evaluation tools
#
# ---
#
# #### 🧠 Step 2: Conversion Process
# A custom function performs the following operations:
# 1. **Loads COCO annotations** (`_annotations.coco.json`) for each dataset split (`train`, `valid`, `test`).
# 2. **Creates YOLO-style folders** — `images/` and `labels/`.
# 3. **Converts segmentation polygons** into **YOLO-normalized coordinates** (values between 0 and 1).
# 4. **Generates YOLO label files** (`.txt`) in the format:
# 5. **Copies images** into the respective YOLO `images/` directory.
# 6. **Processes all splits automatically** to ensure consistency.
#
# ---
#
# #### 🔁 Step 3: Split Processing
# All three dataset splits — **train**, **valid**, and **test** — are converted sequentially.
# The final YOLO-formatted dataset is saved inside:
# /kaggle/working/dataset/
# │
# ├── train/
# │ ├── images/
# │ └── labels/
# │
# ├── valid/
# │ ├── images/
# │ └── labels/
# │
# └── test/
# ├── images/
# └── labels/
#
# ---
#
# Each `.txt` file corresponds to its image and contains polygon coordinates describing the segmentation mask in YOLO format.
# All coordinates are **normalized** relative to image width and height.

# %%
import os, json, shutil
from tqdm import tqdm

def coco_to_yolo_segmentation(coco_json, output_dir):
    with open(coco_json, 'r') as f:
        data = json.load(f)

    # Prepare mapping
    id_to_filename = {img['id']: img['file_name'] for img in data['images']}
    os.makedirs(os.path.join(output_dir, 'images'), exist_ok=True)
    os.makedirs(os.path.join(output_dir, 'labels'), exist_ok=True)

    # Copy images and make YOLO labels
    for ann in tqdm(data['annotations'], desc=f"Converting {coco_json}"):
        image_id = ann['image_id']
        category_id = ann['category_id'] - 1  # YOLO expects 0-based class IDs
        segmentation = ann['segmentation'][0]

        # Normalize segmentation points
        image_info = next((img for img in data['images'] if img['id'] == image_id), None)
        w, h = image_info['width'], image_info['height']
        seg_norm = [f"{x/w:.6f} {y/h:.6f}" for x, y in zip(segmentation[::2], segmentation[1::2])]

        # Write label file
        label_path = os.path.join(output_dir, 'labels', id_to_filename[image_id].replace('.jpg', '.txt'))
        with open(label_path, 'w') as f:
            f.write(f"{category_id} " + " ".join(seg_norm) + "\n")

        # Move image to images/ folder
        src_img = os.path.join(os.path.dirname(coco_json), id_to_filename[image_id])
        dst_img = os.path.join(output_dir, 'images', id_to_filename[image_id])
        if os.path.exists(src_img):
            shutil.copy(src_img, dst_img)

# === Convert all splits ===
base = "/kaggle/input/skin-cancer-segmentation"
for split in ['train', 'valid', 'test']:
    coco_file = os.path.join(base, split, "_annotations.coco.json")
    out_dir = os.path.join("/kaggle/working/dataset", split)
    coco_to_yolo_segmentation(coco_file, out_dir)

print("✅ Conversion complete! Dataset now ready in /kaggle/working/dataset/")
# Out:
# Converting /kaggle/input/skin-cancer-segmentation/train/_annotations.coco.json: 100%|██████████| 11903/11903 [01:02<00:00, 191.05it/s]
# Converting /kaggle/input/skin-cancer-segmentation/valid/_annotations.coco.json: 100%|██████████| 2000/2000 [00:10<00:00, 193.71it/s]
# Converting /kaggle/input/skin-cancer-segmentation/test/_annotations.coco.json: 100%|██████████| 1000/1000 [00:04<00:00, 204.23it/s]
# ✅ Conversion complete! Dataset now ready in /kaggle/working/dataset/

# %% [markdown]
# ## Dataset Re-Splitting (80% Train / 10% Validation / 10% Test)
#
# This section **re-splits the entire dataset** into a clean and reproducible
# **80% training, 10% validation, and 10% test** split.
#
# ### 🔹 Why re-splitting is necessary
#
# - The original dataset already contains `train`, `valid`, and `test` folders
# - However, these splits may be:
#   - Uneven
#   - Dataset-specific
#   - Biased due to collection order
# - For **fair evaluation** and **experimental consistency**, a fresh random split is applied
#
# This ensures:
# - No data leakage
# - Balanced distribution across splits
# - Reproducible experiments (fixed random seed)
#
# ---
#
# ### 🔹 Key Steps Performed
#
# #### 1️⃣ Collect All Data
# - All images from existing `train`, `valid`, and `test` directories are gathered
# - Corresponding YOLO segmentation labels (`.txt`) are collected
#
# #### 2️⃣ Temporary Safe Storage
# - All images and labels are moved to a temporary directory:
#
# /kaggle/working/_tmp_all_data/
# ├── images/
# └── labels/
#
# This prevents overwriting or losing files during reorganization.
#
# #### 3️⃣ Randomized Split (80 / 10 / 10)
# - Dataset is shuffled using a fixed random seed (`SEED = 42`)
# - Split ratios:
#   - **80%** → Training
#   - **10%** → Validation
#   - **10%** → Test
#
# #### 4️⃣ Rebuild YOLO-Compatible Structure
# The dataset is reconstructed into the standard YOLO format:
#
# /kaggle/working/dataset/
# ├── train/
# │ ├── images/
# │ └── labels/
# ├── valid/
# │ ├── images/
# │ └── labels/
# └── test/
# ├── images/
# └── labels/
#
#
# Each image has a corresponding segmentation label file with the same filename.
#
# #### 5️⃣ Automatic Verification
# - The final number of images and labels per split is printed
# - This confirms:
#   - No missing labels
#   - Correct distribution
#   - Successful re-split
#
# ---
#
# ### 🔹 Reproducibility & Best Practices
#
# - Fixed random seed ensures identical splits across runs
# - Labels always follow their corresponding images
# - Temporary directory is removed after completion to save disk space
#
# This re-splitting strategy is **safe, reproducible, and fully compatible with YOLO segmentation training

# %%
import os, glob, random, shutil
from pathlib import Path

# ============================================================
# DATASET SPLIT: 80% Train / 10% Val / 10% Test (RE-SPLIT)
# ============================================================

SEED = 42
random.seed(SEED)

BASE_DATASET = "/kaggle/working/dataset"

# Temporary storage to avoid overwrite issues
TMP_DATASET = "/kaggle/working/_tmp_all_data"

# Create temp dirs
os.makedirs(f"{TMP_DATASET}/images", exist_ok=True)
os.makedirs(f"{TMP_DATASET}/labels", exist_ok=True)

# ------------------------------------------------------------
# 1) Collect ALL images from existing train / valid / test
# ------------------------------------------------------------
all_images = []
for split in ["train", "valid", "test"]:
    all_images += glob.glob(f"{BASE_DATASET}/{split}/images/*")

if not all_images:
    raise RuntimeError("❌ No images found to re-split")

# Move images + labels to temp
for img in all_images:
    img_name = os.path.basename(img)
    old_split = img.split("/")[-3]  # train / valid / test
    lbl_src = f"{BASE_DATASET}/{old_split}/labels/{Path(img_name).stem}.txt"

    shutil.move(img, f"{TMP_DATASET}/images/{img_name}")
    if os.path.exists(lbl_src):
        shutil.move(lbl_src, f"{TMP_DATASET}/labels/{Path(img_name).stem}.txt")

# Clean original dataset dirs
for split in ["train", "valid", "test"]:
    shutil.rmtree(f"{BASE_DATASET}/{split}")

# Recreate dataset structure
for split in ["train", "valid", "test"]:
    os.makedirs(f"{BASE_DATASET}/{split}/images", exist_ok=True)
    os.makedirs(f"{BASE_DATASET}/{split}/labels", exist_ok=True)

# ------------------------------------------------------------
# 2) Perform 80 / 10 / 10 split
# ------------------------------------------------------------
image_paths = glob.glob(f"{TMP_DATASET}/images/*")
random.shuffle(image_paths)

n = len(image_paths)
train_end = int(0.8 * n)
val_end   = train_end + int(0.1 * n)

splits = {
    "train": image_paths[:train_end],
    "valid": image_paths[train_end:val_end],
    "test":  image_paths[val_end:]
}

# ------------------------------------------------------------
# 3) Copy back to BASE_DATASET
# ------------------------------------------------------------
for split, imgs in splits.items():
    for img in imgs:
        img_name = os.path.basename(img)
        lbl_name = Path(img_name).stem + ".txt"

        shutil.move(img, f"{BASE_DATASET}/{split}/images/{img_name}")

        lbl_src = f"{TMP_DATASET}/labels/{lbl_name}"
        if os.path.exists(lbl_src):
            shutil.move(lbl_src, f"{BASE_DATASET}/{split}/labels/{lbl_name}")

# Remove temp
shutil.rmtree(TMP_DATASET)

# ------------------------------------------------------------
# 4) Verification
# ------------------------------------------------------------
print("✅ Dataset re-split completed (80/10/10):")
for split in ["train", "valid", "test"]:
    n_img = len(glob.glob(f"{BASE_DATASET}/{split}/images/*"))
    n_lbl = len(glob.glob(f"{BASE_DATASET}/{split}/labels/*"))
    print(f"{split.upper():5s} → images: {n_img}, labels: {n_lbl}")
# Out:
# ✅ Dataset re-split completed (80/10/10):
# TRAIN → images: 11922, labels: 11922
# VALID → images: 1490, labels: 1490
# TEST  → images: 1491, labels: 1491

# %% [markdown]
# ## 🧪 Labeled–Unlabeled Data Preparation for Semi-Supervised Learning
#
# This section prepares the dataset for **semi-supervised learning (SSL)** by
# splitting the training data into **labeled** and **unlabeled** subsets, enabling
# student–teacher or pseudo-labeling workflows using the **Ultralytics YOLO**
# framework.
#
# ---
#
# #### ⚙️ Step 1: Reproducibility and Configuration
# To ensure consistent experimental results:
# - A fixed random seed (`SEED = 42`) is applied
# - Key SSL hyperparameters are defined, including:
#   - **Labeled fraction** (20%)
#   - **Image size**, **batch size**, and **training epochs**
#   - **Pseudo-label confidence threshold**
# - Separate directories are created for labeled and unlabeled data storage
#
# ---
#
# #### 🧠 Step 2: Training Data Collection
# - All images from the original **training split** are collected
# - Images are shuffled randomly to avoid sampling bias
# - Only valid image formats are considered
#
# ---
#
# #### 🔀 Step 3: Labeled / Unlabeled Split
# - The training set is divided into:
#   - **20% labeled images** (with ground-truth annotations)
#   - **80% unlabeled images** (images only)
# - This simulates a realistic low-label learning scenario
#
# ---
#
# #### 📂 Step 4: Data Organization
# - **Labeled subset**:
#   - Images and corresponding YOLO segmentation labels are copied
#   - Missing labels trigger an error to ensure data integrity
# - **Unlabeled subset**:
#   - Only images are copied (labels intentionally excluded)
#
# The resulting structure is:
#
# /kaggle/working/
# ├── ts_labeled/
# │ ├── images/
# │ └── labels/
# └── ts_unlabeled/
# └── images/
#
#
# ---
#
# #### 📝 Step 5: YOLO Dataset Configuration
# - A YOLO-compatible configuration file (`labeled.yaml`) is generated
# - The file defines:
#   - Paths for labeled training data
#   - Validation and test datasets
#   - Number of classes and class names
# - This configuration is used for **supervised teacher model training**
#
# ---
#
# This preparation enables controlled and reproducible **semi-supervised
# experiments**, where labeled data guides initial learning and unlabeled data is
# leveraged through pseudo-labeling or consistency-based training.

# %%
import os, glob, random, shutil, yaml
import numpy as np
from ultralytics import YOLO

# ============================================================
# 0) Reproducibility
# ============================================================
SEED = 42
random.seed(SEED)
np.random.seed(SEED)

# ============================================================
# 1) Paths & constants
# ============================================================
BASE_DATASET = "/kaggle/working/dataset"

LABELED_PATH   = "/kaggle/working/ts_labeled"
UNLABELED_PATH = "/kaggle/working/ts_unlabeled"

os.makedirs(f"{LABELED_PATH}/images", exist_ok=True)
os.makedirs(f"{LABELED_PATH}/labels", exist_ok=True)
os.makedirs(f"{UNLABELED_PATH}/images", exist_ok=True)


LABELED_FRACTION = 0.2   # 20% labeled, 80% unlabeled
TEACHER_EPOCHS   = 50
STUDENT_EPOCHS   = 50
IMGSZ            = 640
BATCH            = 8
DEVICE           = 0                
PSEUDO_CONF_TH   = 0.6          
MAX_PSEUDO       = None
NUM_CLASSES = 2
CLASS_NAMES = ["affected", "non"]

# ============================================================
# 2) Collect training images
# ============================================================
all_train_imgs = [
    p for p in glob.glob(f"{BASE_DATASET}/train/images/*.*")
    if p.lower().endswith((".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"))
]

if not all_train_imgs:
    raise RuntimeError("No training images found")

random.shuffle(all_train_imgs)

# ============================================================
# 3) 20% labeled / 80% unlabeled split
# ============================================================
split_idx = int(len(all_train_imgs) * LABELED_FRACTION)

labeled_imgs   = all_train_imgs[:split_idx]
unlabeled_imgs = all_train_imgs[split_idx:]

# ============================================================
# 4) Copy labeled data (images + labels)
# ============================================================
def copy_labeled(image_paths, dst_root):
    for img in image_paths:
        base = os.path.splitext(os.path.basename(img))[0]
        lbl  = img.replace("/images/", "/labels/").rsplit(".", 1)[0] + ".txt"
        shutil.copy(img, f"{dst_root}/images/{os.path.basename(img)}")
        if not os.path.exists(lbl):
            raise RuntimeError(f"Missing label for {img}")
        shutil.copy(lbl, f"{dst_root}/labels/{base}.txt")

# ============================================================
# 5) Copy unlabeled data (images only)
# ============================================================
def copy_unlabeled(image_paths, dst_root):
    for img in image_paths:
        shutil.copy(img, f"{dst_root}/images/{os.path.basename(img)}")

copy_labeled(labeled_imgs, LABELED_PATH)
copy_unlabeled(unlabeled_imgs, UNLABELED_PATH)

# ============================================================
# 6) Create YAML for LABELED training
# ============================================================
labeled_yaml = {
    "path": "/kaggle/working",
    "train": "ts_labeled/images",
    "val": "dataset/valid/images",
    "test": "dataset/test/images",
    "nc": NUM_CLASSES,
    "names": CLASS_NAMES
}

yaml_path = "/kaggle/working/labeled.yaml"
with open(yaml_path, "w") as f:
    yaml.dump(labeled_yaml, f)

print(f"✅ Labeled YAML created at {yaml_path}")
print(f"📊 Labeled: {len(labeled_imgs)}, Unlabeled: {len(unlabeled_imgs)}")
print("✅ SSL split + YAML creation completed")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✅ Labeled YAML created at /kaggle/working/labeled.yaml
# 📊 Labeled: 2384, Unlabeled: 9538
# ✅ SSL split + YAML creation completed

# %% [markdown]
# ## 📝 YOLO Dataset Configuration for Labeled Training
#
# This section generates a **YOLO-compatible dataset configuration file**
# (`ts_labeled.yaml`) used for **supervised training of the teacher model** on the
# labeled subset.
#
# ---
#
# #### ⚙️ Step 1: Configuration Definition
# The YAML file specifies:
# - **Root dataset path** (`/kaggle/working`)
# - **Training data** → labeled images (`ts_labeled/images`)
# - **Validation data** → original validation split
# - **Test data** → original test split
# - **Number of classes** and **class names**
#
# ---
#
# #### 📄 Step 2: YAML File Generation
# - The configuration is written using `yaml.safe_dump`
# - Key ordering is preserved for readability
# - The generated file is printed to confirm correctness
#
# ---
#
# The resulting configuration file enables seamless integration with the
# Ultralytics YOLO training pipeline and ensures consistent evaluation using fixed
# validation and test sets.

# %%
DATA_YAML_LABELED = "/kaggle/working/ts_labeled.yaml"
with open(DATA_YAML_LABELED, "w") as f:
    yaml.safe_dump({
        "path": "/kaggle/working",
        "train": "ts_labeled/images",
        "val":   "dataset/valid/images",
        "test":  "dataset/test/images",
        "nc": NUM_CLASSES,
        "names": CLASS_NAMES
    }, f, sort_keys=False)

print(open(DATA_YAML_LABELED).read())
# Out:
# path: /kaggle/working
# train: ts_labeled/images
# val: dataset/valid/images
# test: dataset/test/images
# nc: 2
# names:
# - affected
# - non

# %% [markdown]
# ## 🎓 Teacher Model Training on Labeled Data
#
# This section trains the **teacher segmentation model** using only the labeled
# subset of the dataset. The trained teacher serves as the supervision source for
# subsequent pseudo-label generation in the semi-supervised learning pipeline.
#
# ---
#
# #### ⚙️ Step 1: Model Initialization
# - A **YOLO11 segmentation architecture** is initialized
# - Pretrained weights (`yolo11n.pt`) are loaded to leverage transfer learning
# - The segmentation head enables pixel-level mask prediction
#
# ---
#
# #### 🧠 Step 2: Supervised Training
# The teacher model is trained using:
# - The labeled dataset configuration (`ts_labeled.yaml`)
# - Fixed image resolution and batch size
# - Automatic mixed precision (AMP) for faster and memory-efficient training
# - Early stopping with patience to prevent overfitting
#
# Training artifacts are saved under:
#
# /kaggle/working/ts_runs/teacher_yolo11_seg/
#
#
# ---
#
# #### 💾 Step 3: Best Model Selection
# - The best-performing model checkpoint (based on validation performance) is
#   automatically saved
# - The checkpoint is explicitly reloaded to ensure it is used for downstream
#   pseudo-label generation
#
# ---
#
# This trained teacher model provides reliable predictions on unlabeled data,
# forming the foundation of the semi-supervised segmentation framework.

# %%
# ============================================================
# 3) Train Teacher on the labeled subset
# ============================================================
teacher = YOLO("yolo11-seg.yaml").load("yolo11n.pt")  # init model with seg head + pretrained backbone
teacher_results = teacher.train(
    data=DATA_YAML_LABELED,
    epochs=TEACHER_EPOCHS,
    imgsz=IMGSZ,
    batch=BATCH,
    device=DEVICE,
    project="/kaggle/working/ts_runs",
    name="teacher_yolo11_seg",
    exist_ok=True,
    patience=10,
    amp=True
)
teacher_best = f"{teacher_results.save_dir}/weights/best.pt"
print("✅ Teacher best:", teacher_best)

# Reload best weights explicitly
teacher = YOLO(teacher_best)
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 113.8MB/s 0.0s
# Transferred 499/561 items from pretrained weights
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/ts_labeled.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11-seg.yaml, momentum=0.937, mosaic=1.0, multi_scale=False, name=teacher_yolo11_seg, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=yolo11n.pt, profile=False, project=/kaggle/working/ts_runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/ts_runs/teacher_yolo11_seg, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 24.2MB/s 0.0s
# Overriding model.yaml nc=80 with nc=2
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    683830  ultralytics.nn.modules.head.Segment          [2, 32, 64, [64, 128, 256]]
# YOLO11-seg summary: 203 layers, 2,842,998 parameters, 2,842,982 gradients, 9.7 GFLOPs
#
# Transferred 510/561 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read:
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#                    all       1490       1490      0.983      0.988      0.994      0.895      0.984      0.988      0.994      0.879
#               affected       1490       1490      0.983      0.988      0.994      0.895      0.984      0.988      0.994      0.879
# Speed: 0.2ms preprocess, 2.4ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to /kaggle/working/ts_runs/teacher_yolo11_seg
# ✅ Teacher best: /kaggle/working/ts_runs/teacher_yolo11_seg/weights/best.pt

# %% [markdown]
# ## 🏷️ Pseudo-Label Generation for Unlabeled Data
#
# This section generates **pseudo-labels** for the unlabeled training images using
# the trained **teacher segmentation model**. Only predictions with sufficient
# confidence are retained to ensure label quality.
#
# ---
#
# #### ⚙️ Step 1: Unlabeled Image Selection
# - All unlabeled images are selected for pseudo-labeling
# - An optional upper bound (`MAX_PSEUDO`) can limit the number of processed images
# - A confidence threshold (`PSEUDO_CONF_TH`) controls prediction acceptance
#
# ---
#
# #### 🧠 Step 2: Teacher Inference
# - Each unlabeled image is passed through the trained teacher model
# - Predictions include bounding boxes, class labels, and segmentation masks
# - Images without valid detections or masks are skipped
#
# ---
#
# #### 🎯 Step 3: Confidence-Based Filtering
# - Predictions with confidence scores below the threshold are discarded
# - Only high-confidence detections contribute to pseudo-labels
# - This reduces noise and prevents error propagation
#
# ---
#
# #### 🧩 Step 4: Segmentation Polygon Processing
# - Segmentation masks are converted to polygon representations
# - When multiple polygons exist, the **largest-area polygon** is selected
# - Polygon coordinates are normalized by image width and height
# - Labels are written in **YOLO segmentation format**:
#
#
# <class_id> x1 y1 x2 y2 ... xn yn
#
#
# ---
#
# #### 📂 Step 5: Pseudo-Labeled Dataset Creation
# - Pseudo-labeled images and generated label files are stored separately:
#
#
# /kaggle/working/ts_pseudo/
# ├── images/
# └── labels/
#
#
# ---
#
# This pseudo-labeled dataset augments the limited labeled data and is later merged
# with ground-truth annotations to train the student model in a semi-supervised
# learning framework.

# %%
to_label = unlabeled_imgs if MAX_PSEUDO is None else unlabeled_imgs[:MAX_PSEUDO]
print(f"📝 Pseudo-labeling {len(to_label)} unlabeled images (conf ≥ {PSEUDO_CONF_TH})")
PSEUDO_PATH = "/kaggle/working/ts_pseudo"

os.makedirs(f"{PSEUDO_PATH}/images", exist_ok=True)
os.makedirs(f"{PSEUDO_PATH}/labels", exist_ok=True)

def write_seg_label_file(out_txt, classes, masks_xy, orig_shape):
    """
    Write YOLO segmentation polygons to txt:
    <cls> x1 y1 x2 y2 ... (normalized)
    """
    H, W = orig_shape
    with open(out_txt, "w") as f:
        for cls_id, poly in zip(classes, masks_xy):
            if poly is None or len(poly) < 3:
                continue
            poly = np.array(poly, dtype=np.float32)
            poly[:, 0] = np.clip(poly[:, 0] / W, 0.0, 1.0)
            poly[:, 1] = np.clip(poly[:, 1] / H, 0.0, 1.0)
            coords = " ".join(f"{x:.6f}" for x in poly.reshape(-1))
            f.write(f"{int(cls_id)} {coords}\n")

for img_path in tqdm(to_label, desc="Generating pseudo-labels"):
    results = teacher.predict(
        source=img_path,
        imgsz=IMGSZ,
        conf=PSEUDO_CONF_TH,
        save=False,
        verbose=False
    )

    r = results[0]  # ✅ FIXED

    if r.boxes is None or r.masks is None:
        continue

    confs = r.boxes.conf.cpu().numpy()
    keep_idx = np.where(confs >= PSEUDO_CONF_TH)[0]
    if keep_idx.size == 0:
        continue

    classes = []
    masks_xy = []

    for i in keep_idx:
        if r.masks.xy is None:
            continue

        polys = r.masks.xy[i]
        if isinstance(polys, list):
            areas = [cv2.contourArea(np.array(p, dtype=np.float32))
                     for p in polys if len(p) >= 3]
            if not areas:
                continue
            poly = polys[int(np.argmax(areas))]
        else:
            poly = polys

        if poly is None or len(poly) < 3:
            continue

        cls_id = int(r.boxes.cls[i].item())
        classes.append(cls_id)
        masks_xy.append(poly)

    if not masks_xy:
        continue
        
    base = os.path.splitext(os.path.basename(img_path))[0]
    out_img = f"{PSEUDO_PATH}/images/{os.path.basename(img_path)}"
    out_lbl = f"{PSEUDO_PATH}/labels/{base}.txt"

    H, W = r.orig_shape
    write_seg_label_file(out_lbl, classes, masks_xy, (H, W))
    shutil.copy(img_path, out_img)

print("✅ Pseudo-labels done.")
# Out:
# 📝 Pseudo-labeling 9538 unlabeled images (conf ≥ 0.6)
# Generating pseudo-labels: 100%|██████████| 9538/9538 [02:33<00:00, 62.30it/s]
# ✅ Pseudo-labels done.

# %% [markdown]
# ## 🔗 Merging Labeled and Pseudo-Labeled Data for SSL Training
#
# This section constructs the final training dataset for **semi-supervised learning**
# by merging the ground-truth labeled data with the high-confidence pseudo-labeled
# samples generated by the teacher model.
#
# ---
#
# #### ⚙️ Step 1: Merged Dataset Initialization
# - A dedicated directory is created for the merged dataset
# - Existing files are cleared to ensure clean and repeatable runs
# - Separate `images/` and `labels/` folders are maintained in YOLO format
#
# ---
#
# #### 🧠 Step 2: Priority-Aware Data Merging
# - **Labeled data is merged first**, ensuring that ground-truth annotations take
#   precedence
# - **Pseudo-labeled data is merged second**
# - Filename collisions are resolved by preserving the original labeled samples,
#   preventing pseudo-labels from overwriting true annotations
#
# ---
#
# #### 📂 Step 3: Final Training Dataset Structure
# The resulting dataset is organized as:
#
#
# /kaggle/working/ts_merged/
# ├── images/
# └── labels/
#
#
# This combined dataset increases the effective training set size while maintaining
# annotation reliability.
#
# ---
#
# #### 📝 Step 4: YOLO Configuration for SSL Retraining
# - A new YOLO dataset configuration file (`ts_merged.yaml`) is generated
# - The file defines:
#   - Merged training data
#   - Original validation and test splits
#   - Number of classes and class names
#
# ---
#
# The merged dataset enables **student model retraining** using both ground-truth
# and pseudo-labeled data, completing the semi-supervised segmentation pipeline.

# %%
# ============================================================
# 5) Merge labeled and pseudo-labeled into one training set
# ============================================================
MERGED_PATH = "/kaggle/working/ts_merged"
def ensure_empty(dir_path):
    os.makedirs(dir_path, exist_ok=True)
    for f in glob.glob(f"{dir_path}/*"):
        os.remove(f)

# Clean merged dirs (important for reruns)
ensure_empty(f"{MERGED_PATH}/images")
ensure_empty(f"{MERGED_PATH}/labels")

def safe_merge(src, dst):
    for f in glob.glob(f"{src}/*"):
        name = os.path.basename(f)
        dst_path = os.path.join(dst, name)
        if not os.path.exists(dst_path):
            shutil.copy(f, dst_path)
        # else: keep existing file (ground-truth wins)

# Merge labeled FIRST (ground truth has priority)
safe_merge(f"{LABELED_PATH}/images", f"{MERGED_PATH}/images")
safe_merge(f"{LABELED_PATH}/labels", f"{MERGED_PATH}/labels")

# Merge pseudo-labeled SECOND
safe_merge(f"{PSEUDO_PATH}/images",  f"{MERGED_PATH}/images")
safe_merge(f"{PSEUDO_PATH}/labels",  f"{MERGED_PATH}/labels")

# ============================================================
# Create YAML for SSL retraining
# ============================================================
DATA_YAML_MERGED = "/kaggle/working/ts_merged.yaml"

with open(DATA_YAML_MERGED, "w") as f:
    yaml.safe_dump({
        "path": "/kaggle/working",
        "train": "ts_merged/images",
        "val":   "dataset/valid/images",
        "test":  "dataset/test/images",
        "nc": NUM_CLASSES,
        "names": CLASS_NAMES
    }, f, sort_keys=False)

print(open(DATA_YAML_MERGED).read())
print("✅ Merged dataset + YAML ready for SSL retraining")
# Out:
# path: /kaggle/working
# train: ts_merged/images
# val: dataset/valid/images
# test: dataset/test/images
# nc: 2
# names:
# - affected
# - non
#
# ✅ Merged dataset + YAML ready for SSL retraining

# %% [markdown]
# ## 🎓 Student Model Training on Merged Dataset
#
# This section trains the **student segmentation model** using the merged dataset
# that combines **ground-truth labeled data** with **high-confidence pseudo-labeled
# samples**. This stage represents the core learning step of the semi-supervised
# framework.
#
# ---
#
# #### ⚙️ Step 1: Model Initialization
# - A **YOLO11 segmentation architecture** is initialized
# - Pretrained weights are loaded to accelerate convergence and stabilize training
# - The model is configured identically to the teacher for fair comparison
#
# ---
#
# #### 🧠 Step 2: Semi-Supervised Training
# The student model is trained on the merged dataset using:
# - The merged dataset configuration (`ts_merged.yaml`)
# - Fixed image resolution and batch size
# - Automatic mixed precision (AMP) for computational efficiency
# - Early stopping based on validation performance
#
# Training outputs are saved under:
#
# /kaggle/working/ts_runs/student_yolo11_seg/
#
#
# ---
#
# #### 💾 Step 3: Best Model Selection
# - The best-performing student model checkpoint is automatically saved
# - The final checkpoint is retained for evaluation and comparison
#
# ---
#
# This student model learns from both manual annotations and teacher-generated
# pseudo-labels, completing the semi-supervised segmentation pipeline.

# %%
# ============================================================
# 6) Train Student on merged dataset
# ============================================================
student = YOLO("yolo11-seg.yaml").load("yolo11n.pt")
student_results = student.train(
    data=DATA_YAML_MERGED,
    epochs=STUDENT_EPOCHS,
    imgsz=IMGSZ,
    batch=BATCH,
    device=DEVICE,
    project="/kaggle/working/ts_runs",
    name="student_yolo11_seg",
    exist_ok=True,
    patience=10,
    amp=True
)
student_best = f"{student_results.save_dir}/weights/best.pt"
print("✅ Student best:", student_best)
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Transferred 499/561 items from pretrained weights
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/ts_merged.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11-seg.yaml, momentum=0.937, mosaic=1.0, multi_scale=False, name=student_yolo11_seg, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=yolo11n.pt, profile=False, project=/kaggle/working/ts_runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/ts_runs/student_yolo11_seg, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    683830  ultralytics.nn.modules.head.Segment          [2, 32, 64, [64, 128, 256]]
# YOLO11-seg summary: 203 layers, 2,842,998 parameters, 2,842,982 gradients, 9.7 GFLOPs
#
# Transferred 510/561 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read:
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      2.34G     0.3495     0.5616     0.1732     0.9239          5        640: 100% ━━━━━━━━━━━━ 1461/1461 5.9it/s 4:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 7.1it/s 13.2s
#                    all       1490       1490      0.988       0.99      0.994      0.899      0.989      0.991      0.994      0.884
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      2.34G     0.3453     0.5583     0.1696     0.9241          5        640: 100% ━━━━━━━━━━━━ 1461/1461 5.9it/s 4:10
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 6.8it/s 13.9s
#                    all       1490       1490      0.988       0.99      0.994        0.9      0.989      0.991      0.994      0.884
#
# 50 epochs completed in 3.693 hours.
# Optimizer stripped from /kaggle/working/ts_runs/student_yolo11_seg/weights/last.pt, 6.0MB
# Optimizer stripped from /kaggle/working/ts_runs/student_yolo11_seg/weights/best.pt, 6.0MB
#
# Validating /kaggle/working/ts_runs/student_yolo11_seg/weights/best.pt...
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11-seg summary (fused): 113 layers, 2,834,958 parameters, 0 gradients, 9.6 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 7.0it/s 13.5s
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#                    all       1490       1490      0.988      0.991      0.994        0.9      0.989      0.992      0.994      0.884
#               affected       1490       1490      0.988      0.991      0.994        0.9      0.989      0.992      0.994      0.884
# Speed: 0.2ms preprocess, 2.4ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to /kaggle/working/ts_runs/student_yolo11_seg
# ✅ Student best: /kaggle/working/ts_runs/student_yolo11_seg/weights/best.pt

# %% [markdown]
# ## 📈 Training and Validation Curve Visualization
#
# This section visualizes the **training and validation performance curves** of the
# student YOLOv11 segmentation model.
#
# The script automatically locates the `results.png` file generated by the
# Ultralytics training pipeline and displays it without hard-coding file paths.
# The figure summarizes key training dynamics, including loss convergence and
# evaluation metrics across epochs, providing a concise overview of model
# optimization behavior.

# %%
import os
import matplotlib.pyplot as plt

RUN_DIR = "/kaggle/working/ts_runs/student_yolo11_seg"

# Automatically find results.png
results_png = None
for f in os.listdir(RUN_DIR):
    if f.lower() == "results.png":
        results_png = os.path.join(RUN_DIR, f)
        break

if results_png is None:
    raise FileNotFoundError("❌ results.png not found in YOLO run directory")

# Plot
plt.figure(figsize=(10, 6))
plt.imshow(plt.imread(results_png))
plt.axis("off")
plt.title("Student YOLOv11-Seg: Training & Validation Curves")
plt.show()

# %% [markdown]
# ## 📊 Model Evaluation on Validation Set
#
# This section evaluates the trained **student segmentation model** on a held-out
# validation set to measure its generalization performance.
#
# ---
#
# #### ⚙️ Step 1: Validation Inference
# - The student model is evaluated using the built-in YOLO validation pipeline
# - Validation is performed on data not seen during training
# - All metrics are computed automatically by the Ultralytics framework
#
# ---
#
# #### 📈 Step 2: Metric Reporting
# - Full evaluation metrics are printed for transparency
# - Key segmentation performance indicators are extracted:
#   - **Mask mAP@0.5**
#   - **Mask mAP@0.5:0.95**
#
# These metrics quantify segmentation accuracy across varying IoU thresholds and
# are used for model comparison and reporting.
#
# ---
#
# This evaluation step provides an objective measure of the effectiveness of the
# semi-supervised learning approach prior to final testing.

# %%
# Validation on held-out validation set
val_results = student.val(split="val")

# Print all metrics
print(val_results.results_dict)

# Extract key metrics for report
mask_map50 = val_results.results_dict.get("metrics/mAP50(M)", None)
mask_map5095 = val_results.results_dict.get("metrics/mAP50-95(M)", None)

print(f"Mask mAP@0.5: {mask_map50}")
print(f"Mask mAP@0.5:0.95: {mask_map5095}")
# Out:
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11-seg summary (fused): 113 layers, 2,834,958 parameters, 0 gradients, 9.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 581.9±214.9 MB/s, size: 23.3 KB)
# val: Scanning /kaggle/working/dataset/valid/labels.cache... 1490 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1490/1490 2.4Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 8.0it/s 11.7s
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#                    all       1490       1490      0.988       0.99      0.994        0.9      0.989      0.991      0.994      0.885
#               affected       1490       1490      0.988       0.99      0.994        0.9      0.989      0.991      0.994      0.885
# Speed: 0.7ms preprocess, 2.5ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/segment/val
# {'metrics/precision(B)': 0.9880065842783683, 'metrics/recall(B)': 0.9899328859060402, 'metrics/mAP50(B)': 0.9935944858085584, 'metrics/mAP50-95(B)': 0.900147043033748, 'metrics/precision(M)': 0.9893462542231525, 'metrics/recall(M)': 0.991275167785235, 'metrics/mAP50(M)': 0.9940532741693938, 'metrics/mAP50-95(M)': 0.8846117886746454, 'fitness': 1.7847588317083933}
# Mask mAP@0.5: 0.9940532741693938
# Mask mAP@0.5:0.95: 0.8846117886746454

# %% [markdown]
# ## 👁️ Qualitative Visualization of Segmentation Results
#
# This section presents a **qualitative comparison** between ground-truth
# segmentation masks and predictions generated by the trained **student model** on
# the validation dataset.
#
# ---
#
# #### ⚙️ Step 1: Sample Selection
# - A small subset of images is randomly selected from the validation split
# - These samples were not used during training, ensuring unbiased visualization
#
# ---
#
# #### 🧠 Step 2: Model Inference
# - The trained student model performs segmentation inference on each image
# - All predicted instance masks are merged into a single binary mask per image
# - Predictions are generated using the same confidence threshold applied during
# pseudo-labeling
#
# ---
#
# #### 🎯 Step 3: Ground-Truth Mask Reconstruction
# - YOLO segmentation labels are converted back into pixel-level masks
# - Polygon coordinates are denormalized and rasterized to form binary masks
#
# ---
#
# #### 📊 Step 4: Visual Comparison
# For each sample, three views are displayed:
# 1. Original RGB image
# 2. Ground-truth segmentation mask
# 3. Student model prediction
#
# This visual inspection complements quantitative metrics by highlighting boundary
# accuracy, shape consistency, and potential failure cases of the model.
#
# ---
#
# Qualitative analysis provides intuitive insight into the segmentation performance
# and helps validate the effectiveness of the semi-supervised learning framework.

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
import glob, os
from ultralytics import YOLO

valid_images = glob.glob(f"{BASE_DATASET}/valid/images/*")[:5]
model = YOLO("/kaggle/working/ts_runs/student_yolo11_seg/weights/best.pt")

for img_path in valid_images:
    img = cv2.imread(img_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    pred = model.predict(
        source=img,
        conf=PSEUDO_CONF_TH,
        imgsz=IMGSZ,
        verbose=False
    )[0]

    # ------------------------
    # Predicted mask (merge all instances)
    # ------------------------
    pred_mask = np.zeros((img.shape[0], img.shape[1]), dtype=np.uint8)
    if pred.masks is not None:
        for m in pred.masks.data:
            m = m.cpu().numpy().astype(np.uint8)
            m = cv2.resize(m, (img.shape[1], img.shape[0]))
            pred_mask = np.maximum(pred_mask, m)

    # ------------------------
    # Ground truth mask
    # ------------------------
    label_path = img_path.replace("images", "labels").rsplit(".", 1)[0] + ".txt"
    gt_mask = np.zeros((img.shape[0], img.shape[1]), dtype=np.uint8)

    if os.path.exists(label_path):
        for line in open(label_path):
            cls, *coords = map(float, line.strip().split())
            pts = np.array(coords, np.float32).reshape(-1, 2)
            pts[:, 0] *= img.shape[1]
            pts[:, 1] *= img.shape[0]
            cv2.fillPoly(gt_mask, [pts.astype(np.int32)], 1)

    # ------------------------
    # Visualization
    # ------------------------
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 3, 1)
    plt.title("Image")
    plt.imshow(img_rgb)
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.title("Ground Truth")
    plt.imshow(gt_mask, cmap="gray")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.title("Prediction")
    plt.imshow(pred_mask, cmap="gray")
    plt.axis("off")

    plt.show()

# %%
import cv2
import numpy as np
import glob, os
from ultralytics import YOLO
from tqdm import tqdm

# ============================================================
# Config
# ============================================================
BASE_DATASET = "/kaggle/working/dataset"
IMGSZ = 640
PSEUDO_CONF_TH = 0.7

MODEL_PATH = "/kaggle/working/ts_runs/student_yolo11_seg/weights/best.pt"
# ⚠️ Update if path differs

# ============================================================
# IoU function
# ============================================================
def compute_iou(pred_mask, gt_mask):
    pred_mask = pred_mask.astype(bool)
    gt_mask   = gt_mask.astype(bool)

    intersection = np.logical_and(pred_mask, gt_mask).sum()
    union        = np.logical_or(pred_mask, gt_mask).sum()

    if union == 0:
        return 1.0 if intersection == 0 else 0.0

    return intersection / union

# ============================================================
# Load model
# ============================================================
model = YOLO(MODEL_PATH)

# ============================================================
# Collect ALL validation images
# ============================================================
valid_images = sorted(glob.glob(f"{BASE_DATASET}/valid/images/*"))
assert len(valid_images) > 0, "No validation images found"

ious = []

# ============================================================
# Evaluation loop
# ============================================================
for img_path in tqdm(valid_images, desc= "Evaluating mIoU"):
    img = cv2.imread(img_path)
    if img is None:
        continue

    H, W = img.shape[:2]

    # ------------------------
    # Prediction
    # ------------------------
    pred = model.predict(
        source=img,
        imgsz=IMGSZ,
        conf=PSEUDO_CONF_TH,
        verbose=False
    )[0]

    # ------------------------
    # Predicted mask (polygon-based)
    # ------------------------
    pred_mask = np.zeros((H, W), dtype=np.uint8)

    if pred.masks is not None:
        for poly in pred.masks.xy:
            if poly is None or len(poly) < 3:
                continue
            pts = np.array(poly, np.int32)
            cv2.fillPoly(pred_mask, [pts], 1)

    # ------------------------
    # Ground truth mask
    # ------------------------
    gt_mask = np.zeros((H, W), dtype=np.uint8)
    label_path = img_path.replace("images", "labels").rsplit(".", 1)[0] + ".txt"

    if os.path.exists(label_path):
        with open(label_path) as f:
            for line in f:
                _, *coords = map(float, line.strip().split())
                pts = np.array(coords, np.float32).reshape(-1, 2)
                pts[:, 0] *= W
                pts[:, 1] *= H
                cv2.fillPoly(gt_mask, [pts.astype(np.int32)], 1)

    # ------------------------
    # IoU
    # ------------------------
    iou = compute_iou(pred_mask, gt_mask)
    ious.append(iou)

# ============================================================
# Final Mean IoU
# ============================================================
mean_iou = float(np.mean(ious)) if ious else 0.0
print(f"\n✅ Mean IoU on validation set ({len(ious)} images): {mean_iou:.4f}")
# Out:
# Evaluating mIoU: 100%|██████████| 1490/1490 [00:24<00:00, 59.97it/s]
# ✅ Mean IoU on validation set (1490 images): 0.8877
